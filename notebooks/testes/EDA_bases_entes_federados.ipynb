# %%
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importar tabela de meta de alfabetização por município
df_meta_municipio = pd.read_parquet('../data/meta_alfabetizacao_municipio.parquet')
df_meta_municipio.head()
# Out:
#     ano id_municipio id_municipio_nome       rede  taxa_alfabetizacao  \
# 0  2023      4301750  Barão do Triunfo  Municipal                 NaN
# 1  2024      4301750  Barão do Triunfo  Municipal                4.40
# 2  2024      2406908          Lucrécia  Municipal               42.86
# 3  2023      2406908          Lucrécia  Municipal                4.40
# 4  2023      1718501     Recursolândia  Municipal                4.60
#
#    meta_alfabetizacao_2024  meta_alfabetizacao_2025  meta_alfabetizacao_2026  \
# 0                      NaN                    14.05                    23.65
# 1                      NaN                    14.05                    23.65
# 2                     7.94                    14.05                    23.65
# 3                     7.94                    14.05                    23.65
# 4                     8.25                    14.48                    24.16
#
#    meta_alfabetizacao_2027  meta_alfabetizacao_2028  meta_alfabetizacao_2029  \
# 0                    37.00                    52.68                    67.85
# 1                    37.00                    52.68                    67.85
# 2                    37.00                    52.68                    67.85
# 3                    37.00                    52.68                    67.85
# 4                    37.49                    53.03                    68.00
#
#    meta_alfabetizacao_2030  nivel_alfabetizacao  percentual_participacao
# 0                     80.0                 <NA>                      NaN
# 1                     80.0                    0                    92.59
# 2                     80.0                    1                    84.00
# 3                     80.0                    0                    82.14
# 4                     80.0                    0                    95.65

# %%
len(df_meta_municipio)
# Out:
# 10704

# %%
# Verificar dados nulos
df_meta_municipio.isna().sum()
# Out:
# ano                          0
# id_municipio                 0
# id_municipio_nome            0
# rede                         0
# taxa_alfabetizacao         120
# meta_alfabetizacao_2024    240
# meta_alfabetizacao_2025      0
# meta_alfabetizacao_2026      0
# meta_alfabetizacao_2027      0
# meta_alfabetizacao_2028      0
# meta_alfabetizacao_2029      0
# meta_alfabetizacao_2030      0
# nivel_alfabetizacao        120
# percentual_participacao    120
# dtype: int64

# %%
# Entender relação entre dados nulos das colunas taxa_alfabetizacao e meta_alfabetizacao_2024
df_meta_municipio[df_meta_municipio['taxa_alfabetizacao'].isna()][['ano', 'id_municipio','taxa_alfabetizacao', 'meta_alfabetizacao_2024']]
# Out:
#        ano id_municipio  taxa_alfabetizacao  meta_alfabetizacao_2024
# 0     2023      4301750                 NaN                      NaN
# 8     2023      2414456                 NaN                      NaN
# 13    2023      2406205                 NaN                      NaN
# 21    2023      2408706                 NaN                      NaN
# 26    2023      1200435                 NaN                      NaN
# ...    ...          ...                 ...                      ...
# 8844  2023      4216008                 NaN                      NaN
# 8846  2023      3147501                 NaN                      NaN
# 8848  2023      3151909                 NaN                      NaN
# 8850  2023      3166600                 NaN                      NaN
# 8851  2023      3306156                 NaN                      NaN
#
# [120 rows x 4 columns]

# %%
len(df_meta_municipio[df_meta_municipio['meta_alfabetizacao_2024'].isna()]['id_municipio'].unique())
# Out:
# 120

# %% [markdown]
# Sempre que o município não tem meta em 2024, ele não tem taxa de alfabetização em 2023.
#
# Para resolver esse problema, temos duas opções:
# a) trabalhar apenas com os dados de taxa de alfabetização de 2024;
# b) copiar a taxa de 2024 em 2023 e a meta de 2025 para 2024;

# %%
# Conferindo se a coluna taxa_alfabetizacao possui algum dado menor que 0 ou acima de 100, que podem indicar dados inconsistentes.
df_meta_municipio['taxa_alfabetizacao'].describe()
# Out:
# count    10584.000000
# mean        61.774719
# std         19.527540
# min          4.400000
# 25%         47.600000
# 50%         62.445000
# 75%         76.742500
# max        100.000000
# Name: taxa_alfabetizacao, dtype: float64

# %%
# Comparar com a base município
df_municipio = pd.read_parquet('../data/municipio.parquet')
df_municipio.head()
# Out:
#     ano id_municipio id_municipio_nome                         serie  \
# 0  2023      1100031            Cabixi  2° ano do Ensino Fundamental
# 1  2023      1100072        Corumbiara  2° ano do Ensino Fundamental
# 2  2023      1100189     Pimenta Bueno  2° ano do Ensino Fundamental
# 3  2023      1101609         Theobroma  2° ano do Ensino Fundamental
# 4  2023      1101807   Vale do Paraíso  2° ano do Ensino Fundamental
#
#   chave_rede                            rede  taxa_alfabetizacao  \
# 0          3                       Municipal               69.10
# 1          3                       Municipal               58.20
# 2          5  Pública (Estadual e Municipal)               69.73
# 3          3                       Municipal               50.70
# 4          3                       Municipal               55.69
#
#    media_portugues  proporcao_aluno_nivel_0  proporcao_aluno_nivel_1  \
# 0         767.8763                      NaN                      NaN
# 1         747.8918                      NaN                      NaN
# 2         762.4062                      NaN                      NaN
# 3         745.6802                      NaN                      NaN
# 4         752.3724                      NaN                      NaN
#
#    proporcao_aluno_nivel_2  proporcao_aluno_nivel_3  proporcao_aluno_nivel_4  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    proporcao_aluno_nivel_5  proporcao_aluno_nivel_6  proporcao_aluno_nivel_7  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    proporcao_aluno_nivel_8
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
df_municipio['chave_rede'].value_counts()

# %%
# Entendendo a quantidade de municípios em cada base:
print(f'A base Meta Municipio possui {len(df_meta_municipio['id_municipio'].unique())} municípios distintos.')
print(f'A base Municipio possui {len(df_municipio['id_municipio'].unique())} municípios distintos.')
# Out:
# A base Meta Municipio possui 5352 municípios distintos.
# A base Municipio possui 5550 municípios distintos.

# %%
def compara_bases(df1, df2):
    bases_unidas = pd.merge(df1, df2, on=['ano', 'id_municipio', 'rede'], how='left')
    bases_unidas['taxa_diferente'] = (bases_unidas['taxa_alfabetizacao_x'] != bases_unidas['taxa_alfabetizacao_y']).astype(int)
    return bases_unidas

# %%
compara_taxa_alfabetizacao = compara_bases(df_meta_municipio, df_municipio[['ano', 'id_municipio', 'taxa_alfabetizacao', 'rede']])
print(f'Existem {len(compara_taxa_alfabetizacao[compara_taxa_alfabetizacao['taxa_diferente'] == 1])} linhas com taxas diferentes para um mesmo município em cada base.')
# Out:
# Existem 4716 linhas com taxas diferentes para um mesmo município em cada base.

# %%
# Listando os municípios com taxas diferentes para entender a diferença.
compara_taxa_alfabetizacao[compara_taxa_alfabetizacao['taxa_diferente'] == 1].sort_values('id_municipio')
# Out:
#         ano id_municipio      id_municipio_nome       rede  \
# 6102   2023      1100015  Alta Floresta D'Oeste  Municipal
# 5740   2023      1100049                 Cacoal  Municipal
# 4908   2023      1100056             Cerejeiras  Municipal
# 5811   2023      1100064      Colorado do Oeste  Municipal
# 9463   2023      1100080          Costa Marques  Municipal
# ...     ...          ...                    ...        ...
# 10472  2023      5221908                 Varjão  Municipal
# 9488   2023      5222005             Vianópolis  Municipal
# 8524   2023      5222054         Vicentinópolis  Municipal
# 10438  2023      5222203               Vila Boa  Municipal
# 7941   2023      5222302          Vila Propício  Municipal
#
#        taxa_alfabetizacao_x  meta_alfabetizacao_2024  meta_alfabetizacao_2025  \
# 6102                   64.6                    67.08                    69.51
# 5740                   62.5                    65.39                    68.16
# 4908                   58.5                    62.09                    65.53
# 5811                   62.9                    65.67                    68.39
# 9463                   80.7                    80.00                    80.00
# ...                     ...                      ...                      ...
# 10472                  97.7                    80.00                    80.00
# 9488                   89.0                    80.00                    80.00
# 8524                   78.2                    78.50                    78.75
# 10438                  83.8                    80.00                    80.00
# 7941                   74.4                    75.29                    76.13
#
#        meta_alfabetizacao_2026  meta_alfabetizacao_2027  \
# 6102                     71.84                    74.06
# 5740                     70.81                    73.33
# 4908                     68.81                    71.91
# 5811                     70.98                    73.45
# 9463                     80.00                    80.00
# ...                        ...                      ...
# 10472                    80.00                    80.00
# 9488                     80.00                    80.00
# 8524                     79.01                    79.26
# 10438                    80.00                    80.00
# 7941                     76.94                    77.74
#
#        meta_alfabetizacao_2028  meta_alfabetizacao_2029  \
# 6102                     76.16                    78.14
# 5740                     75.70                    77.92
# 4908                     74.81                    77.51
# 5811                     75.78                    77.96
# 9463                     80.00                    80.00
# ...                        ...                      ...
# 10472                    80.00                    80.00
# 9488                     80.00                    80.00
# 8524                     79.51                    79.76
# 10438                    80.00                    80.00
# 7941                     78.51                    79.26
#
#        meta_alfabetizacao_2030  nivel_alfabetizacao  percentual_participacao  \
# 6102                      80.0                    3                    89.37
# 5740                      80.0                    3                    84.44
# 4908                      80.0                    2                    92.12
# 5811                      80.0                    3                    86.98
# 9463                      80.0                    5                    91.06
# ...                        ...                  ...                      ...
# 10472                     80.0                    5                    78.18
# 9488                      80.0                    5                    84.88
# 8524                      80.0                    4                    94.20
# 10438                     80.0                    5                    92.11
# 7941                      80.0                    4                    90.54
#
#        taxa_alfabetizacao_y  taxa_diferente
# 6102                  64.55               1
# 5740                  62.51               1
# 4908                  58.53               1
# 5811                  62.85               1
# 9463                  80.68               1
# ...                     ...             ...
# 10472                 97.74               1
# 9488                  89.04               1
# 8524                  78.24               1
# 10438                 83.76               1
# 7941                  74.44               1
#
# [4716 rows x 16 columns]

# %% [markdown]
# É possível notar que as notas são as taxas do dataframe Meta Município estão arredondando para 1 casa decimal, por isso a diferença.

# %%
compara_taxa_alfabetizacao[compara_taxa_alfabetizacao['taxa_diferente'] == 1].isna().sum()
# Out:
# ano                          0
# id_municipio                 0
# id_municipio_nome            0
# rede                         0
# taxa_alfabetizacao_x       120
# meta_alfabetizacao_2024    120
# meta_alfabetizacao_2025      0
# meta_alfabetizacao_2026      0
# meta_alfabetizacao_2027      0
# meta_alfabetizacao_2028      0
# meta_alfabetizacao_2029      0
# meta_alfabetizacao_2030      0
# nivel_alfabetizacao        120
# percentual_participacao    120
# taxa_alfabetizacao_y        50
# taxa_diferente               0
# dtype: int64

# %% [markdown]
# Apesar de constatarmos que as bases apresentam taxas de alfabetização semelhante, a base Município possui menos dados em branco.

# %%
# Entender a coluna rede
df_meta_municipio['rede'].value_counts()
# Out:
# rede
# Municipal    10704
# Name: count, dtype: int64

# %%
df_municipio['rede'].value_counts()
# Out:
# rede
# Municipal                                         10896
# Pública (Estadual e Municipal)                    10466
# Estadual                                           2235
# Total (Federal, Estadual, Municipal e Privada)      398
# Name: count, dtype: int64

# %% [markdown]
# Como a base município possui mais redes listadas, preferimos usar a taxa de alfabetização desta base.

# %%
# Analisando as bases UF e Meta UF

df_uf = pd.read_parquet('../data/uf.parquet')
df_uf.head()
# Out:
#     ano sigla_uf sigla_uf_nome                         serie  \
# 0  2023       AM      Amazonas  2° ano do Ensino Fundamental
# 1  2023       PB       Paraíba  2° ano do Ensino Fundamental
# 2  2023       PR        Paraná  2° ano do Ensino Fundamental
# 3  2023       AP         Amapá  2° ano do Ensino Fundamental
# 4  2023       PE    Pernambuco  2° ano do Ensino Fundamental
#
#                              rede  taxa_alfabetizacao  media_portugues  \
# 0                       Municipal               49.20         733.6637
# 1                        Estadual               55.23         744.8152
# 2  Pública (Estadual e Municipal)               73.12         757.2146
# 3                       Municipal               41.87         732.7858
# 4  Pública (Estadual e Municipal)               58.95         747.4522
#
#    proporcao_aluno_nivel_0  proporcao_aluno_nivel_1  proporcao_aluno_nivel_2  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    proporcao_aluno_nivel_3  proporcao_aluno_nivel_4  proporcao_aluno_nivel_5  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    proporcao_aluno_nivel_6  proporcao_aluno_nivel_7  proporcao_aluno_nivel_8
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN

# %%
df_meta_uf = pd.read_parquet('../data/meta_alfabetizacao_uf.parquet')
df_meta_uf
# Out:
#      ano sigla_uf sigla_uf_nome     rede  taxa_alfabetizacao  \
# 0   2024       RR       Roraima  Pública                 NaN
# 1   2023       RR       Roraima  Pública                 NaN
# 2   2024       SE       Sergipe  Pública               38.39
# 3   2023       SE       Sergipe  Pública               31.30
# 4   2025       SE       Sergipe  Pública               50.00
# ..   ...      ...           ...      ...                 ...
# 76  2023       PR        Paraná  Pública               73.12
# 77  2024       PR        Paraná  Pública               70.42
# 78  2025       CE         Ceará  Pública               84.00
# 79  2024       CE         Ceará  Pública               85.31
# 80  2023       CE         Ceará  Pública               84.50
#
#     meta_alfabetizacao_2024  meta_alfabetizacao_2025  meta_alfabetizacao_2026  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                      38.3                     45.9                     53.6
# 3                      38.3                     45.9                     53.6
# 4                      38.0                     46.0                     54.0
# ..                      ...                      ...                      ...
# 76                     74.2                     75.2                     76.2
# 77                     74.2                     75.2                     76.2
# 78                     80.0                     80.0                     80.0
# 79                     80.0                     80.0                     80.0
# 80                     80.0                     80.0                     80.0
#
#     meta_alfabetizacao_2027  meta_alfabetizacao_2028  meta_alfabetizacao_2029  \
# 0                       NaN                      NaN                      NaN
# 1                       NaN                      NaN                      NaN
# 2                      61.2                     68.3                     74.6
# 3                      61.2                     68.3                     74.6
# 4                      61.0                     68.0                     75.0
# ..                      ...                      ...                      ...
# 76                     77.2                     78.2                     79.1
# 77                     77.2                     78.2                     79.1
# 78                     80.0                     80.0                     80.0
# 79                     80.0                     80.0                     80.0
# 80                     80.0                     80.0                     80.0
#
#     meta_alfabetizacao_2030  percentual_participacao
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                      80.0                    92.84
# 3                      80.0                    88.34
# 4                      80.0                    87.00
# ..                      ...                      ...
# 76                     80.0                    86.18
# 77                     80.0                    86.25
# 78                     80.0                    96.00
# 79                     80.0                    98.13
# 80                     80.0                    95.22
#
# [81 rows x 13 columns]

# %%
df_uf['rede'].value_counts()
# Out:
# rede
# Municipal                                         49
# Pública (Estadual e Municipal)                    49
# Estadual                                          46
# Total (Federal, Estadual, Municipal e Privada)     1
# Name: count, dtype: int64

# %%
df_meta_uf['rede'].value_counts()
# Out:
# rede
# Pública    81
# Name: count, dtype: int64

# %%
df_meta_brasil = pd.read_parquet('../data/meta_alfabetizacao_brasil.parquet')
df_meta_brasil.head()
# Out:
#     ano     rede  taxa_alfabetizacao  meta_alfabetizacao_2024  \
# 0  2025  Pública                66.0                     60.0
# 1  2024  Pública                59.2                     59.9
# 2  2023  Pública                55.9                     59.9
#
#    meta_alfabetizacao_2025  meta_alfabetizacao_2026  meta_alfabetizacao_2027  \
# 0                    64.00                    67.00                    71.00
# 1                    63.77                    67.47                    70.97
# 2                    63.77                    67.47                    70.97
#
#    meta_alfabetizacao_2028  meta_alfabetizacao_2029  meta_alfabetizacao_2030  \
# 0                    74.00                    77.00                     80.0
# 1                    74.23                    77.24                     80.0
# 2                    74.23                    77.24                     80.0
#
#    percentual_participacao
# 0                    88.00
# 1                    87.37
# 2                    86.00

# %% [markdown]
# A princípio, não vamos usar as bases de meta para o modelo, porque só trazem informações da rede pública.
#
# Vamos acrescentar então as informações que devem entrar no modelo.

# %%
# Os municípios não tem a UF vinculada nesta base. Então vamos juntar esta informação aqui.

df_diretorios_municipio = pd.read_parquet('../data/dir_municipio.parquet')
df_diretorios_municipio.head()
# Out:
#   id_municipio sigla_uf
# 0      5101837       MT
# 1      1100205       RO
# 2      1100338       RO
# 3      1100809       RO
# 4      1101104       RO

# %%
acrescenta_dados_uf = pd.merge(
    df_municipio, df_diretorios_municipio, on=['id_municipio'], how='right'
)
print('Dados em branco na coluna sigla_uf: ', acrescenta_dados_uf['sigla_uf'].isna().sum())
print('Tamanho dataset antes do merge: ', len(df_municipio))
print('Tamanho dataset depois do merge: ', len(acrescenta_dados_uf))
# Out:
# Dados em branco na coluna sigla_uf:  0
# Tamanho dataset antes do merge:  23995
# Tamanho dataset depois do merge:  24016

# %%
# Acrescenta taxa de alfabetização da tabela uf

df_com_dados_de_taxa_de_alfabetizacao_da_uf = pd.merge(
    acrescenta_dados_uf, df_uf[['sigla_uf', 'ano', 'taxa_alfabetizacao', 'rede']], on=['sigla_uf', 'ano', 'rede'], how='left',
    suffixes=('_mun', '_uf')
)
print('Dados em branco na coluna taxa_alfabetizacao_uf: ', df_com_dados_de_taxa_de_alfabetizacao_da_uf['taxa_alfabetizacao_uf'].isna().sum())
print('Tamanho dataset antes do merge: ', len(acrescenta_dados_uf))
print('Tamanho dataset depois do merge: ', len(df_com_dados_de_taxa_de_alfabetizacao_da_uf))
# Out:
# Dados em branco na coluna taxa_alfabetizacao_uf:  23
# Tamanho dataset antes do merge:  24016
# Tamanho dataset depois do merge:  24016

# %%
# Vamos entender quais são os dados que ficaram em branco:

df_com_dados_de_taxa_de_alfabetizacao_da_uf[df_com_dados_de_taxa_de_alfabetizacao_da_uf['taxa_alfabetizacao_uf'].isna()]
# Out:
#         ano id_municipio id_municipio_nome                         serie  \
# 0      <NA>      5101837               NaN                           NaN
# 639    <NA>      1400050               NaN                           NaN
# 640    <NA>      1400100               NaN                           NaN
# 641    <NA>      1400027               NaN                           NaN
# 642    <NA>      1400456               NaN                           NaN
# 643    <NA>      1400175               NaN                           NaN
# 644    <NA>      1400159               NaN                           NaN
# 645    <NA>      1400407               NaN                           NaN
# 646    <NA>      1400704               NaN                           NaN
# 647    <NA>      1400308               NaN                           NaN
# 648    <NA>      1400209               NaN                           NaN
# 649    <NA>      1400282               NaN                           NaN
# 650    <NA>      1400472               NaN                           NaN
# 651    <NA>      1400233               NaN                           NaN
# 652    <NA>      1400506               NaN                           NaN
# 653    <NA>      1400605               NaN                           NaN
# 19988  <NA>      4301925               NaN                           NaN
# 20165  <NA>      4315958               NaN                           NaN
# 20653  <NA>      4322350               NaN                           NaN
# 21194  <NA>      4305835               NaN                           NaN
# 23704  <NA>      5219308               NaN                           NaN
# 24014  2024      5300108          Brasília  2° ano do Ensino Fundamental
# 24015  2024      5300108          Brasília  2° ano do Ensino Fundamental
#
#       chave_rede                            rede  taxa_alfabetizacao_mun  \
# 0            NaN                             NaN                     NaN
# 639          NaN                             NaN                     NaN
# 640          NaN                             NaN                     NaN
# 641          NaN                             NaN                     NaN
# 642          NaN                             NaN                     NaN
# 643          NaN                             NaN                     NaN
# 644          NaN                             NaN                     NaN
# 645          NaN                             NaN                     NaN
# 646          NaN                             NaN                     NaN
# 647          NaN                             NaN                     NaN
# 648          NaN                             NaN                     NaN
# 649          NaN                             NaN                     NaN
# 650          NaN                             NaN                     NaN
# 651          NaN                             NaN                     NaN
# 652          NaN                             NaN                     NaN
# 653          NaN                             NaN                     NaN
# 19988        NaN                             NaN                     NaN
# 20165        NaN                             NaN                     NaN
# 20653        NaN                             NaN                     NaN
# 21194        NaN                             NaN                     NaN
# 23704        NaN                             NaN                     NaN
# 24014          5  Pública (Estadual e Municipal)                   59.13
# 24015          2                        Estadual                   59.13
#
#        media_portugues  proporcao_aluno_nivel_0  proporcao_aluno_nivel_1  \
# 0                  NaN                      NaN                      NaN
# 639                NaN                      NaN                      NaN
# 640                NaN                      NaN                      NaN
# 641                NaN                      NaN                      NaN
# 642                NaN                      NaN                      NaN
# 643                NaN                      NaN                      NaN
# 644                NaN                      NaN                      NaN
# 645                NaN                      NaN                      NaN
# 646                NaN                      NaN                      NaN
# 647                NaN                      NaN                      NaN
# 648                NaN                      NaN                      NaN
# 649                NaN                      NaN                      NaN
# 650                NaN                      NaN                      NaN
# 651                NaN                      NaN                      NaN
# 652                NaN                      NaN                      NaN
# 653                NaN                      NaN                      NaN
# 19988              NaN                      NaN                      NaN
# 20165              NaN                      NaN                      NaN
# 20653              NaN                      NaN                      NaN
# 21194              NaN                      NaN                      NaN
# 23704              NaN                      NaN                      NaN
# 24014           743.01                     2.44                     4.67
# 24015           743.01                     2.44                     4.67
#
#        proporcao_aluno_nivel_2  proporcao_aluno_nivel_3  \
# 0                          NaN                      NaN
# 639                        NaN                      NaN
# 640                        NaN                      NaN
# 641                        NaN                      NaN
# 642                        NaN                      NaN
# 643                        NaN                      NaN
# 644                        NaN                      NaN
# 645                        NaN                      NaN
# 646                        NaN                      NaN
# 647                        NaN                      NaN
# 648                        NaN                      NaN
# 649                        NaN                      NaN
# 650                        NaN                      NaN
# 651                        NaN                      NaN
# 652                        NaN                      NaN
# 653                        NaN                      NaN
# 19988                      NaN                      NaN
# 20165                      NaN                      NaN
# 20653                      NaN                      NaN
# 21194                      NaN                      NaN
# 23704                      NaN                      NaN
# 24014                     7.66                     9.63
# 24015                     7.66                     9.63
#
#        proporcao_aluno_nivel_4  proporcao_aluno_nivel_5  \
# 0                          NaN                      NaN
# 639                        NaN                      NaN
# 640                        NaN                      NaN
# 641                        NaN                      NaN
# 642                        NaN                      NaN
# 643                        NaN                      NaN
# 644                        NaN                      NaN
# 645                        NaN                      NaN
# 646                        NaN                      NaN
# 647                        NaN                      NaN
# 648                        NaN                      NaN
# 649                        NaN                      NaN
# 650                        NaN                      NaN
# 651                        NaN                      NaN
# 652                        NaN                      NaN
# 653                        NaN                      NaN
# 19988                      NaN                      NaN
# 20165                      NaN                      NaN
# 20653                      NaN                      NaN
# 21194                      NaN                      NaN
# 23704                      NaN                      NaN
# 24014                    25.61                    33.05
# 24015                    25.61                    33.05
#
#        proporcao_aluno_nivel_6  proporcao_aluno_nivel_7  \
# 0                          NaN                      NaN
# 639                        NaN                      NaN
# 640                        NaN                      NaN
# 641                        NaN                      NaN
# 642                        NaN                      NaN
# 643                        NaN                      NaN
# 644                        NaN                      NaN
# 645                        NaN                      NaN
# 646                        NaN                      NaN
# 647                        NaN                      NaN
# 648                        NaN                      NaN
# 649                        NaN                      NaN
# 650                        NaN                      NaN
# 651                        NaN                      NaN
# 652                        NaN                      NaN
# 653                        NaN                      NaN
# 19988                      NaN                      NaN
# 20165                      NaN                      NaN
# 20653                      NaN                      NaN
# 21194                      NaN                      NaN
# 23704                      NaN                      NaN
# 24014                    13.13                      3.1
# 24015                    13.13                      3.1
#
#        proporcao_aluno_nivel_8 sigla_uf  taxa_alfabetizacao_uf
# 0                          NaN       MT                    NaN
# 639                        NaN       RR                    NaN
# 640                        NaN       RR                    NaN
# 641                        NaN       RR                    NaN
# 642                        NaN       RR                    NaN
# 643                        NaN       RR                    NaN
# 644                        NaN       RR                    NaN
# 645                        NaN       RR                    NaN
# 646                        NaN       RR                    NaN
# 647                        NaN       RR                    NaN
# 648                        NaN       RR                    NaN
# 649                        NaN       RR                    NaN
# 650                        NaN       RR                    NaN
# 651                        NaN       RR                    NaN
# 652                        NaN       RR                    NaN
# 653                        NaN       RR                    NaN
# 19988                      NaN       RS                    NaN
# 20165                      NaN       RS                    NaN
# 20653                      NaN       RS                    NaN
# 21194                      NaN       RS                    NaN
# 23704                      NaN       GO                    NaN
# 24014                     0.71       DF                    NaN
# 24015                     0.71       DF                    NaN

# %% [markdown]
# Estes municípios acima, exceto Brasília, não têm taxa calculada para a UF nos anos 2023 e 2024.
#
# A situação de Brasília chama atenção.
#
# Devido a natureza híbrida do Distrito Federal, ele não tem taxa de alfabetização como UF, apenas como município e só tem taxa em 2024.

# %%
# Copiando os dados do DF como município para 
condicao = (df_com_dados_de_taxa_de_alfabetizacao_da_uf['sigla_uf'] == 'DF') & (df_com_dados_de_taxa_de_alfabetizacao_da_uf['taxa_alfabetizacao_uf'].isna())
df_com_dados_de_taxa_de_alfabetizacao_da_uf.loc[condicao, 'taxa_alfabetizacao_uf'] = df_com_dados_de_taxa_de_alfabetizacao_da_uf.loc[condicao, 'taxa_alfabetizacao_mun']
df_com_dados_de_taxa_de_alfabetizacao_da_uf[df_com_dados_de_taxa_de_alfabetizacao_da_uf['sigla_uf'] == 'DF']
# Out:
#         ano id_municipio id_municipio_nome                         serie  \
# 24014  2024      5300108          Brasília  2° ano do Ensino Fundamental
# 24015  2024      5300108          Brasília  2° ano do Ensino Fundamental
#
#       chave_rede                            rede  taxa_alfabetizacao_mun  \
# 24014          5  Pública (Estadual e Municipal)                   59.13
# 24015          2                        Estadual                   59.13
#
#        media_portugues  proporcao_aluno_nivel_0  proporcao_aluno_nivel_1  \
# 24014           743.01                     2.44                     4.67
# 24015           743.01                     2.44                     4.67
#
#        proporcao_aluno_nivel_2  proporcao_aluno_nivel_3  \
# 24014                     7.66                     9.63
# 24015                     7.66                     9.63
#
#        proporcao_aluno_nivel_4  proporcao_aluno_nivel_5  \
# 24014                    25.61                    33.05
# 24015                    25.61                    33.05
#
#        proporcao_aluno_nivel_6  proporcao_aluno_nivel_7  \
# 24014                    13.13                      3.1
# 24015                    13.13                      3.1
#
#        proporcao_aluno_nivel_8 sigla_uf  taxa_alfabetizacao_uf
# 24014                     0.71       DF                  59.13
# 24015                     0.71       DF                  59.13

# %%
# Baixar bases socioeconômicas para agregar a base do modelo
indice_analf = pd.read_parquet('../data/outras_fontes/indice_analfabetismo.parquet')
inse = pd.read_parquet('../data/outras_fontes/inse.parquet')
rendimento_per_capta = pd.read_parquet('../data/outras_fontes/rendimento_dom_per_capta.parquet')

# %%
# Entendendo as bases a serem usadas e fazendo a junção.
indice_analf.head()
# Out:
#   Sigla   Código     Município  indice_analf
# 0    AC  1200013    Acrelândia         11.65
# 1    AC  1200054  Assis Brasil         14.70
# 2    AC  1200104     Brasiléia         10.99
# 3    AC  1200138        Bujari         18.74
# 4    AC  1200179      Capixaba         15.73

# %%
# Precisamos renomear as colunas e padronizar o tipo.

indice_analf['id_municipio'] = indice_analf['Código']
indice_analf['id_municipio'] = indice_analf['id_municipio'].astype(str)
indice_analf.drop('Código', axis = 1, inplace=True)

# %%
agrega_bases_externas = pd.merge(df_com_dados_de_taxa_de_alfabetizacao_da_uf, indice_analf[['id_municipio', 'indice_analf']], how='left', on= 'id_municipio')

print('Dados em branco na coluna indice_analf: ', agrega_bases_externas['indice_analf'].isna().sum())
print('Tamanho dataset antes do merge: ', len(df_com_dados_de_taxa_de_alfabetizacao_da_uf))
print('Tamanho dataset depois do merge: ', len(agrega_bases_externas))
# Out:
# Dados em branco na coluna indice_analf:  0
# Tamanho dataset antes do merge:  24016
# Tamanho dataset depois do merge:  24016

# %%
# Adicionada a base de índice de analfabetismo, vamos entender a base com os dados socioeconômicos.

inse.head()
# Out:
#    NU_ANO_SAEB  CO_MUNICIPIO  TP_TIPO_REDE  MEDIA_INSE
# 0         2023       1100015             0       4.948
# 1         2023       1100015             2       4.981
# 2         2023       1100015             3       4.964
# 3         2023       1100015             5       4.948
# 4         2023       1100015             6       4.948

# %%
inse['NU_ANO_SAEB'].value_counts()
# Out:
# NU_ANO_SAEB
# 2023    28978
# Name: count, dtype: int64

# %%
# Precisamos renomear as colunas e padronizar o tipo.

inse['id_municipio'] = inse['CO_MUNICIPIO'].astype(str)
inse['chave_rede'] = inse['TP_TIPO_REDE'].astype(str)
inse.drop('CO_MUNICIPIO', axis = 1, inplace=True)
inse.drop('TP_TIPO_REDE', axis = 1, inplace=True)
inse.head()
# Out:
#    NU_ANO_SAEB  MEDIA_INSE id_municipio chave_rede
# 0         2023       4.948      1100015          0
# 1         2023       4.981      1100015          2
# 2         2023       4.964      1100015          3
# 3         2023       4.948      1100015          5
# 4         2023       4.948      1100015          6

# %%
agrega_bases_externas_inse = pd.merge(agrega_bases_externas, inse, how='left', left_on=['ano','id_municipio', 'chave_rede'], right_on=['NU_ANO_SAEB','id_municipio', 'chave_rede'])

print('Dados em branco na coluna MEDIA_INSE: ', agrega_bases_externas_inse['MEDIA_INSE'].isna().sum())
print('Tamanho dataset antes do merge: ', len(agrega_bases_externas))
print('Tamanho dataset depois do merge: ', len(agrega_bases_externas_inse))
# Out:
# Dados em branco na coluna MEDIA_INSE:  12518
# Tamanho dataset antes do merge:  24016
# Tamanho dataset depois do merge:  24016

# %% [markdown]
# Como vimos acima, a base do INSE só contém dados do ano de 2023. Portanto, como nosso interesse é usar os dados de 2023 para prever o desempenho dos alunos de 2024, vamos eliminar os dados de 2024 da base.
#
# Como só existem dados de Brasília-DF no ano de 2024. Depois de agregarmos esta base com a base de alunos, precisamos definir o que fazer com os alunos deste local.

# %%
# Vamos usar apenas o ano de 2023, então precisamos filtrar as linhas com o ano de 2023 e as colunas sem ano, 
# que são os municípios que não possuem taxa de alfabetização. Se tirarmos esses e o município tiver aluno 
# avaliado em 2024, ficará sem os dados agregados.

agrega_bases_externas_inse_2023 = agrega_bases_externas_inse.query('ano == 2023 or ano.isna()')
print('Tamanho inicial do dataset de municípios: ', len(df_municipio))
print('Tamanho dataset depois do merge: ', len(agrega_bases_externas_inse_2023))

print('Dados em branco na coluna MEDIA_INSE: ', agrega_bases_externas_inse_2023['MEDIA_INSE'].isna().sum())
# Out:
# Tamanho inicial do dataset de municípios:  23995
# Tamanho dataset depois do merge:  11568
# Dados em branco na coluna MEDIA_INSE:  70

# %% [markdown]
# Consideramos que 70 linhas em branco em um dataset com 11547 é aceitável. Então, vamos só checar o restante das colunas antes de gravar esta base.

# %%
agrega_bases_externas_inse_2023.isna().sum()
# Out:
# ano                           21
# id_municipio                   0
# id_municipio_nome             21
# serie                         21
# chave_rede                    21
# rede                          21
# taxa_alfabetizacao_mun        21
# media_portugues               21
# proporcao_aluno_nivel_0    11568
# proporcao_aluno_nivel_1    11568
# proporcao_aluno_nivel_2    11568
# proporcao_aluno_nivel_3    11568
# proporcao_aluno_nivel_4    11568
# proporcao_aluno_nivel_5    11568
# proporcao_aluno_nivel_6    11568
# proporcao_aluno_nivel_7    11568
# proporcao_aluno_nivel_8    11568
# sigla_uf                       0
# taxa_alfabetizacao_uf         21
# indice_analf                   0
# NU_ANO_SAEB                   70
# MEDIA_INSE                    70
# dtype: int64

# %%
# Vamos excluir as colunas de proporção, uma vez que o dado não foi gerado em 2023. Excluiremos, também, as colunas redundantes.

cols_to_drop = [
    'proporcao_aluno_nivel_0', 'proporcao_aluno_nivel_1', 'proporcao_aluno_nivel_2', 'proporcao_aluno_nivel_3', 
    'proporcao_aluno_nivel_4', 'proporcao_aluno_nivel_5', 'proporcao_aluno_nivel_6', 'proporcao_aluno_nivel_7',
    'proporcao_aluno_nivel_8', 'NU_ANO_SAEB']
df_municipio_final = agrega_bases_externas_inse_2023.drop(columns=[c for c in cols_to_drop if c in agrega_bases_externas_inse_2023.columns])
df_municipio_final
# Out:
#         ano id_municipio id_municipio_nome                         serie  \
# 0      <NA>      5101837               NaN                           NaN
# 1      2023      1100205       Porto Velho  2° ano do Ensino Fundamental
# 2      2023      1100205       Porto Velho  2° ano do Ensino Fundamental
# 3      2023      1100205       Porto Velho  2° ano do Ensino Fundamental
# 7      2023      1100338       Nova Mamoré  2° ano do Ensino Fundamental
# ...     ...          ...               ...                           ...
# 24003  2023      5209150       Gouvelândia  2° ano do Ensino Fundamental
# 24006  2023      5216304      Paranaiguara  2° ano do Ensino Fundamental
# 24007  2023      5216304      Paranaiguara  2° ano do Ensino Fundamental
# 24010  2023      5220405         São Simão  2° ano do Ensino Fundamental
# 24011  2023      5220405         São Simão  2° ano do Ensino Fundamental
#
#       chave_rede                            rede  taxa_alfabetizacao_mun  \
# 0            NaN                             NaN                     NaN
# 1              2                        Estadual                   57.45
# 2              5  Pública (Estadual e Municipal)                   64.47
# 3              3                       Municipal                   65.06
# 7              3                       Municipal                   63.02
# ...          ...                             ...                     ...
# 24003          3                       Municipal                   39.78
# 24006          3                       Municipal                   85.71
# 24007          5  Pública (Estadual e Municipal)                   85.71
# 24010          5  Pública (Estadual e Municipal)                   72.78
# 24011          3                       Municipal                   72.78
#
#        media_portugues sigla_uf  taxa_alfabetizacao_uf  indice_analf  \
# 0                  NaN       MT                    NaN          8.46
# 1             747.2139       RO                  58.65          4.36
# 2             760.4047       RO                  64.60          4.36
# 3             761.5118       RO                  65.17          4.36
# 7             754.3625       RO                  65.17          9.31
# ...                ...      ...                    ...           ...
# 24003         729.4058       GO                  66.72         12.99
# 24006         773.1885       GO                  66.72         10.04
# 24007         773.1885       GO                  66.74         10.04
# 24010         757.9946       GO                  66.74          8.28
# 24011         757.9946       GO                  66.72          8.28
#
#        MEDIA_INSE
# 0             NaN
# 1           4.959
# 2           4.892
# 3           4.789
# 7           4.733
# ...           ...
# 24003       5.071
# 24006       5.398
# 24007       5.341
# 24010       5.337
# 24011       5.413
#
# [11568 rows x 12 columns]

# %%
df_municipio_final['chave_rede'].value_counts()
# Out:
# chave_rede
# 3    5448
# 5    4950
# 2    1149
# Name: count, dtype: int64

# %%
df_municipio_final.to_parquet('../data/dados_modelo/municipio_agregado_outras_fontes.parquet')
